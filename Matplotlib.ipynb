# %% [markdown]
# <a href="https://colab.research.google.com/github/VU21CSEN0100410/DEEPIKA/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints= np.array([0,7])
ypoints= np.array([0,300])
plt.plot( xpoints, ypoints )
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints= np.array([1,5])
ypoints= np.array([1,200])
plt.plot( xpoints, ypoints )
plt.show()

# %% [markdown]
# PLOT WITHOUT LINE

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints= np.array([1,5])
ypoints= np.array([1,200])
plt.plot( xpoints, ypoints,'o' )
plt.show()

# %% [markdown]
# MULTIPLE POINTS

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints= np.array([1,3,5,7])
ypoints= np.array([1,165,53,260])
plt.plot( xpoints, ypoints )
plt.show()

# %% [markdown]
# DEFAULT X POINTS

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([1,3,8,2,9,6,1,10,4,11])
plt.plot( ypoints )
plt.show()

# %% [markdown]
# MATPLOTLIB MARKERS

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([1,3,8,2,9,6,1])
plt.plot( ypoints, marker='o' )
plt.show()

# %% [markdown]
# FORMAT STRINGS fmt

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([1,3,8,2,9,6])
plt.plot( ypoints,'o:r' )
plt.show()

# %% [markdown]
# MARKER SIZE

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([8,2,9,6,1])
plt.plot( ypoints, marker='o',ms=25 )
plt.show()

# %% [markdown]
# MARKER COLOR

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([1,3,2,9,6,1])
plt.plot( ypoints, marker='o',ms=15,mec='r' )
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([1,2,3,2,5,7,1])
plt.plot( ypoints, marker='o',ms=15,mfc='pink' )
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([2,9,6,1])
plt.plot( ypoints, marker='o',ms=25,mec='r',mfc='#4CAF50' )
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([8,7,9,6,1])
plt.plot( ypoints, marker='o',ms=20,mec='#4CAF50',mfc='hotpink')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([6,2,9,6])
plt.plot( ypoints,linestyle='dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([5,2,9,6])
plt.plot( ypoints,ls='dashed')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([8,7,9,6,1])
plt.plot( ypoints, linestyle=':')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([6,6,6,6,4,5,4,3])
plt.plot( ypoints, color='purple')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([2,3,6,2,8,6,1])
plt.plot( ypoints,linewidth='20')
plt.show()

# %% [markdown]
# MULTIPLE LINES

# %%
import matplotlib.pyplot as plt
import numpy as np
y1 = np.array([1, 10, 2, 9])
y2 = np.array([8, 11, 2, 6])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([60, 65, 70, 75, 80, 85, 90, 95])
y = np.array([150, 160, 170, 180, 190, 200, 210, 220])
plt.plot(x, y)
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.show()
